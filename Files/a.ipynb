# %%
from functions import *
from pandas import read_csv

# %%
df=read_csv(r"C:\Users\AshishTSusikaran\Desktop\Neuberg AP\Files\New.csv")

# %%
output=Concatenation(TrueOutStanding(Reconcile(df,'Amount in Local Currency','Account'),'Amount in Local Currency'))

# %%
output.to_csv('output.csv')

# %%
output
# Out:
#        Account  Document Number Business place Document Type  \
# 0   10100232.0     1.000101e+09           33JL            AB
# 1   10100232.0     2.000002e+09           33JL            DR
# 2   10100232.0     2.000002e+09           33JL            DR
# 3   10100232.0     2.000002e+09           33JL            DR
# 4   10100232.0     2.000002e+09           33JL            DR
# ..         ...              ...            ...           ...
# 4   20304924.0     2.000002e+09           33JL            DR
# 0   20306512.0     2.000001e+09           33JL            DR
# 1   20306512.0     2.000001e+09           33JL            DR
# 2   20306512.0     2.000001e+09           33JL            DR
# 3   20306512.0     2.000001e+09           33JL            DR
#
#    Baseline Payment Dte Posting Date Document Date Special G/L Ind.  \
# 0                 45291        45291         45291              NaN
# 1                 45377        45377         45377              NaN
# ...
